# %%
import pandas as pd
import os
import sys
sys.path.append('..')

from urlclustering.noise_feature import digit_ratio, special_char_ratio, pos
from urlclustering.toolkit.noise_sample import read_sample, write_sample

# %%
samples = read_sample('../data/samples.csv')

# %%
samples[samples.word.apply(lambda word: '%' in word)]
# Out:
#                                                      word  \
# 135296                                 %e5%a4%96%e5%a5%97
# 135315                        %e9%bb%83%e8%95%99%e7%8e%b2
# 135321                        %e7%89%9b%e4%bb%94%e8%a4%b2
# 144189  100379395119%3fal_applink_data%3d%257b%2522tar...
# 144296  d65551056%3fal_applink_data%3d%257b%2522target...
# 144341  100533234652%3fal_applink_data%3d%257b%2522tar...
# 144883  100504538914%3fal_applink_data%3d%257b%2522tar...
# 145006  100399611888%3fal_applink_data%3d%257b%2522tar...
# 145234  100533262764%3fal_applink_data%3d%257b%2522tar...
# 145238  100533239659%3fal_applink_data%3d%257b%2522tar...
# 145376  100282691097%3fal_applink_data%3d%257b%2522tar...
# 145618  100533222337%3fal_applink_data%3d%257b%2522tar...
# 145661  100533232983%3fal_applink_data%3d%257b%2522tar...
# 305546  100509760372%3fal_applink_data%3d%257b%2522tar...
# 452606  100534442463%3fal_applink_data%3d%257b%2522tar...
# ...

# %%
samples
# Out:
#                     word                                                url  \
# 0                     v1                     /v1/account/point?a=b&a=b?&f=j
# 1                account                     /v1/account/point?a=b&a=b?&f=j
# 2                  point                     /v1/account/point?a=b&a=b?&f=j
# 3                  users                        /v1/users/Y1373408890/badge
# 4            y1373408890                        /v1/users/Y1373408890/badge
# 5                  badge                        /v1/users/Y1373408890/badge
# 6            y3120228436                        /v1/users/Y3120228436/badge
# 7            y3800282782                        /v1/users/Y3800282782/badge
# 8                   ecid                                   /v1/account/ecid
# 9            y5680668194                        /v1/users/Y5680668194/badge
# 10             watchlist                   /v1/watchlist?offset=0&limit=100
# ...

# %%
samples['position'] = samples.apply(lambda row: pos(row.word, row.url), axis=1)

# %%
samples['special_ratio'] = samples.word.apply(lambda word: special_char_ratio(word))

# %%
write_sample(samples, '../data/samples.csv')
